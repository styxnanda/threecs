# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
works = pd.read_csv('../data/ao3-dump-2021/works-20210226.csv')
tags = pd.read_csv('../data/ao3-dump-2021/tags-20210226.csv')

# %%
works.head(20)
# Out:
#    creation date language  restricted  complete  word_count  \
# 0     2021-02-26       en       False      True       388.0
# 1     2021-02-26       en       False      True      1638.0
# 2     2021-02-26       en       False      True      1502.0
# 3     2021-02-26       en       False      True       100.0
# 4     2021-02-26       en       False      True       994.0
# 5     2021-02-26       en       False      True      3016.0
# 6     2021-02-26       en       False      True      4236.0
# 7     2021-02-26       en       False      True       267.0
# 8     2021-02-26       en       False     False      4249.0
# 9     2021-02-26       en       False      True      2853.0
# 10    2021-02-26       en       False      True      1900.0
# 11    2021-02-26       en       False     False      6260.0
# 12    2021-02-26       en       False      True       558.0
# 13    2021-02-26       en       False      True       634.0
# 14    2021-02-26       en       False     False     17361.0
# ...

# %%
works = works.drop('Unnamed: 6', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 works = works.drop('Unnamed: 6', axis=1)
#       2 works.head(20)
#
# File ~\anaconda3\envs\AO3-SCP\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
works.head(20)
# Out:
#    creation date language  restricted  complete  word_count  \
# 0     2021-02-26       en       False      True       388.0
# 1     2021-02-26       en       False      True      1638.0
# 2     2021-02-26       en       False      True      1502.0
# 3     2021-02-26       en       False      True       100.0
# 4     2021-02-26       en       False      True       994.0
# 5     2021-02-26       en       False      True      3016.0
# 6     2021-02-26       en       False      True      4236.0
# 7     2021-02-26       en       False      True       267.0
# 8     2021-02-26       en       False     False      4249.0
# 9     2021-02-26       en       False      True      2853.0
# 10    2021-02-26       en       False      True      1900.0
# 11    2021-02-26       en       False     False      6260.0
# 12    2021-02-26       en       False      True       558.0
# 13    2021-02-26       en       False      True       634.0
# 14    2021-02-26       en       False     False     17361.0
# ...

# %%
tags.head(30)
# Out:
#     id            type                                name  canonical  \
# 0    1           Media                            TV Shows       True
# 1    2           Media                              Movies       True
# 2    3           Media                  Books & Literature       True
# 3    4           Media  Cartoons & Comics & Graphic Novels       True
# 4    5           Media                       Anime & Manga       True
# 5    6           Media                       Music & Bands       True
# 6    7           Media           Celebrities & Real People       True
# 7    8           Media                         Other Media       True
# 8    9          Rating                           Not Rated       True
# 9   10          Rating                   General Audiences       True
# 10  11          Rating               Teen And Up Audiences       True
# 11  12          Rating                              Mature       True
# ...

# %%
works.shape
# Out:
# (7269693, 6)

# %%
tags.shape
# Out:
# (14467138, 6)

# %%
works['tag_ids'] = works['tags'].str.split('+')

# %%
works.head(5)
# Out:
#   creation date language  restricted  complete  word_count  \
# 0    2021-02-26       en       False      True       388.0
# 1    2021-02-26       en       False      True      1638.0
# 2    2021-02-26       en       False      True      1502.0
# 3    2021-02-26       en       False      True       100.0
# 4    2021-02-26       en       False      True       994.0
#
#                                                 tags  Unnamed: 6  \
# 0  10+414093+1001939+4577144+1499536+110+4682892+...         NaN
# 1  10+20350917+34816907+23666027+23269305+2326930...         NaN
# 2  10+10613413+9780526+3763877+3741104+7657229+30...         NaN
# 3  10+15322+54862755+20595867+32994286+663+471751...         NaN
# 4  11+721553+54604+1439500+3938423+53483274+54862...         NaN
#
#                                              tag_ids
# 0  [10, 414093, 1001939, 4577144, 1499536, 110, 4...
# 1  [10, 20350917, 34816907, 23666027, 23269305, 2...
# 2  [10, 10613413, 9780526, 3763877, 3741104, 7657...
# ...

# %%
works = works.explode('tag_ids')
works.tail(5)
# Out:
#   creation date language  restricted  complete  word_count  \
# 0    2021-02-26       en       False      True       388.0
# 0    2021-02-26       en       False      True       388.0
# 0    2021-02-26       en       False      True       388.0
# 0    2021-02-26       en       False      True       388.0
# 0    2021-02-26       en       False      True       388.0
#
#                                                 tags  Unnamed: 6  tag_ids
# 0  10+414093+1001939+4577144+1499536+110+4682892+...         NaN       10
# 0  10+414093+1001939+4577144+1499536+110+4682892+...         NaN   414093
# 0  10+414093+1001939+4577144+1499536+110+4682892+...         NaN  1001939
# 0  10+414093+1001939+4577144+1499536+110+4682892+...         NaN  4577144
# 0  10+414093+1001939+4577144+1499536+110+4682892+...         NaN  1499536

# %%
works.tail(5)
# Out:
#         creation date language  restricted  complete  word_count  \
# 7269692    2008-09-13       en       False      True      1836.0
# 7269692    2008-09-13       en       False      True      1836.0
# 7269692    2008-09-13       en       False      True      1836.0
# 7269692    2008-09-13       en       False      True      1836.0
# 7269692    2008-09-13       en       False      True      1836.0
#
#                                                       tags  Unnamed: 6 tag_ids
# 7269692  123+124+125+127+128+13+129+14+130+131+132+133+...         NaN    2246
# 7269692  123+124+125+127+128+13+129+14+130+131+132+133+...         NaN    2832
# 7269692  123+124+125+127+128+13+129+14+130+131+132+133+...         NaN    2831
# 7269692  123+124+125+127+128+13+129+14+130+131+132+133+...         NaN     968
# 7269692  123+124+125+127+128+13+129+14+130+131+132+133+...         NaN   39120

# %%
merged_data = works.merge(tags, left_on='tag_ids', right_on='id')
